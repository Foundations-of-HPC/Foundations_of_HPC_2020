# %%
import numpy as np
numproc=np.array([1, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48])

# %%
numproc
# Out:
# array([ 1,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48])

# %%
timeesec=np.array([26.94, 6.91666666666667, 3.64666666666667, 2.62333333333333, 2.13333333333333, 1.9, 1.72333333333333, 1.76, 1.71, 1.71, 1.79, 1.87666666666667, 1.97666666666667])
t1=26.94
Spus=t1/timeesec

# %%
Spus
# Out:
# array([ 1.        ,  3.89493976,  7.38756856, 10.26937738, 12.628125  ,
#        14.17894737, 15.63249516, 15.30681818, 15.75438596, 15.75438596,
#        15.05027933, 14.35523979, 13.62900506])

# %%
timeinter=np.array([27.41100612, 6.61054308, 3.29853151, 2.21828879, 1.67541609, 1.35647902, 1.14945819, 1.03576333, 0.94155652, 0.84628811, 0.77474216, 0.75376713, 0.76673436])
t1i=27.41100612
Spis=t1i/timeinter

# %%
Spis
# Out:
# array([ 1.        ,  4.14655888,  8.31006344, 12.35682488, 16.36071558,
#        20.2074678 , 23.8468927 , 26.46454583, 29.11243833, 32.38968597,
#        35.38081124, 36.36535082, 35.75032964])

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(numproc, Spus, 'r--', label="usr")
plt.plot(numproc, Spis, 'b--', label="int")
plt.xlabel('processors numbers')
plt.ylabel('speedup')
#plt.text(0,.00020, r'$N=2000$')
plt.suptitle('strong scalability per N=10^9')
plt.legend(loc='best')
plt.savefig('N=1miliardos.png')
plt.show()

# %%
import numpy as np
numproc=np.array([1, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48])

# %%
numproc
# Out:
# array([ 1,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48])

# %%
timeesec=np.array([26.5833333333333, 26.82, 27.5866666666667, 27.0866666666667, 27.7166666666667, 29.5766666666667, 33.9033333333333, 30.9033333333333, 32.1666666666667, 32.1966666666667, 32.5066666666667, 32.8433333333333, 35.49])
t1=26.5833333333333
Spuw=t1/timeesec

# %%
Spuw
# Out:
# array([1.        , 0.99117574, 0.96362977, 0.98141767, 0.95911004,
#        0.89879409, 0.78409203, 0.86020925, 0.82642487, 0.82565483,
#        0.81778097, 0.80939815, 0.74903729])

# %%
timeinter=np.array([26.29952739, 26.30850352, 26.39663273, 26.56701298, 26.85926024, 30.52558638, 44.29509099, 30.09017106, 31.13207892, 31.06572622, 31.62034473, 31.22786546, 35.0685509])
t1i=26.29952739
Spiw=t1i/timeinter

# %%
Spiw
# Out:
# array([1.        , 0.99965881, 0.9963213 , 0.98993166, 0.97916053,
#        0.86155683, 0.59373458, 0.87402386, 0.8447726 , 0.84657694,
#        0.83172804, 0.8421814 , 0.74994623])

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(numproc, Spuw, 'r--', label="usr")
plt.plot(numproc, Spiw, 'b--', label="int")
plt.xlabel('processors numbers')
plt.ylabel('speedup')
#plt.text(0,.00020, r'$N=2000$')
plt.suptitle('weak scalability per N=1miliar')
plt.legend(loc='best')
plt.savefig('N=1miliardow.png')
plt.show()
